# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import pprint as pprint
import numpy as np
import glob

# %%
filepath = "/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core"
all_files = glob.glob(filepath + "/*.csv")
all_files
# Out:
# ['/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/Fielding.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/Salaries.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/People.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/Teams.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/Batting.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/FieldingOF.csv',
#  '/Users/ebimoosa/Desktop/SMU/Personal SMU/project 1/smu_project1_baseball/baseballdatabank-master/core/SeriesPost.csv']

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315684 entries, 0 to 315683
# Data columns (total 97 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   playerID        312371 non-null  object
#  1   yearID          295326 non-null  float64
#  2   stint           265585 non-null  float64
#  3   teamID          282940 non-null  object
#  4   lgID            280641 non-null  object
#  5   POS             144768 non-null  object
#  6   G               256512 non-null  float64
#  7   GS              98612 non-null   float64
#  8   InnOuts         114839 non-null  float64
#  9   PO              144768 non-null  float64
#  10  A               144768 non-null  float64
#  11  E               147722 non-null  float64
#  12  DP              147723 non-null  float64
#  13  PB              11709 non-null   float64
#  14  WP              1169 non-null    float64
#  15  SB              118172 non-null  float64
# ...

# %%
# read in csv's


filepath2 = "Core/Batting.csv"

filepath3 = "Core/Salaries.csv"

filepath4 = "Core/People.csv"

filepath5 = "Core/Fielding.csv"

filepath6 = "Core/FieldingOF.csv"

filepath8 = "Core/Teams.csv"

filepath12 = "Core/SeriesPost.csv"


playerAwards_df = pd.read_csv(filepath1)

batting_df = pd.read_csv(filepath2)

salaries_df = pd.read_csv(filepath3)

players_df = pd.read_csv(filepath4)

fielding_df = pd.read_csv(filepath5)

fieldingOF_df = pd.read_csv(filepath6)

pitching_df = pd.read_csv(filepath7)

teams_df = pd.read_csv(filepath8)

batting_post_df = pd.read_csv(filepath9)

pitching_post_df = pd.read_csv(filepath10)

fielding_post_df = pd.read_csv(filepath11)

series_post_df = pd.read_csv(filepath12)

# %%
# .info() for all read csv's

print(playerAwards_df.info())
print(batting_df.info())
print(salaries_df.info())
print(players_df.info())
print(fielding_df.info())
print(fieldingOF_df.info())
print(pitching_df.info())
print(teams_df.info())
print(batting_post_df.info())
print(pitching_post_df.info())
print(fielding_post_df.info())
print(series_post_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6531 entries, 0 to 6530
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   playerID  6531 non-null   object
#  1   awardID   6531 non-null   object
#  2   yearID    6531 non-null   int64
#  3   lgID      6526 non-null   object
#  4   tie       53 non-null     object
#  5   notes     4999 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 306.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108789 entries, 0 to 108788
# Data columns (total 22 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   playerID  108789 non-null  object
#  1   yearID    108789 non-null  int64
#  2   stint     108789 non-null  int64
#  3   teamID    108789 non-null  object
#  4   lgID      108052 non-null  object
#  5   G         108789 non-null  int64
#  6   AB        108789 non-null  int64
# ...
